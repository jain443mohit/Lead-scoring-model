# %% [markdown]
# # Import basic library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# visulaisation
from matplotlib.pyplot import xticks
# %matplotlib inline



# Supress Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("D:\\Documents\\Data_Science_Internship.csv" ,encoding= 'unicode_escape')
df
# Out:
#        Unnamed: 0                                           Agent_id status  \
# 0               0  1deba9e96f404694373de9749ddd1ca8aa7bb823145a6f...   LOST
# 1               1  299ae77a4ef350ae0dd37d6bba1c002d03444fb1edb236...   LOST
# 2               2  c213697430c006013012dd2aca82dd9732aa0a1a6bca13...   LOST
# 3               3  eac9815a500f908736d303e23aa227f0957177b0e6756b...   LOST
# 4               4  1deba9e96f404694373de9749ddd1ca8aa7bb823145a6f...   LOST
# ...           ...                                                ...    ...
# 46603       46603  2306878a9ad9b57686cd623dd285aaa9b25afdf627f651...   LOST
# 46604       46604  327ec29056cc47c24bf922f7dc0f78261dad5c726d7353...   LOST
# 46605       46605  1134c0a7d44fdae1afd7f1f64e2789496784095ca0a050...   LOST
# 46606       46606  8b8b029f1142f5cbc825aa6cbee01406c915c6b055db79...   LOST
# 46607       46607  1ea65ea38f2f574b3875ba895e4ff76b284b7725041612...   LOST
#
#             lost_reason                budget  \
# ...

# %%
df.shape
# Out:
# (46608, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46608 entries, 0 to 46607
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      46608 non-null  int64
#  1   Agent_id        46608 non-null  object
#  2   status          46608 non-null  object
#  3   lost_reason     43244 non-null  object
#  4   budget          42908 non-null  object
#  5   lease           44267 non-null  object
#  6   movein          32970 non-null  object
#  7   source          46608 non-null  object
#  8   source_city     46608 non-null  object
#  9   source_country  46608 non-null  object
#  10  utm_source      46608 non-null  object
#  11  utm_medium      46608 non-null  object
#  12  des_city        46608 non-null  object
#  13  des_country     46608 non-null  object
#  14  room_type       23061 non-null  object
#  15  lead_id         46608 non-null  object
# dtypes: int64(1), object(15)
# memory usage: 5.7+ MB

# %%
df['status'].value_counts()
# Out:
# LOST           43244
# WON             3073
# OPPORTUNITY      254
# CONTACTED         28
# PROCESSING         8
# IMPORTANT          1
# Name: status, dtype: int64

# %% [markdown]
#  The leads with STATUS other than ‘WON’ or ‘LOST’ can be dropped during training.

# %%
df=df[(df['status']=='LOST')|(df['status']=='WON')]
df
# Out:
#        Unnamed: 0                                           Agent_id status  \
# 0               0  1deba9e96f404694373de9749ddd1ca8aa7bb823145a6f...   LOST
# 1               1  299ae77a4ef350ae0dd37d6bba1c002d03444fb1edb236...   LOST
# 2               2  c213697430c006013012dd2aca82dd9732aa0a1a6bca13...   LOST
# 3               3  eac9815a500f908736d303e23aa227f0957177b0e6756b...   LOST
# 4               4  1deba9e96f404694373de9749ddd1ca8aa7bb823145a6f...   LOST
# ...           ...                                                ...    ...
# 46603       46603  2306878a9ad9b57686cd623dd285aaa9b25afdf627f651...   LOST
# 46604       46604  327ec29056cc47c24bf922f7dc0f78261dad5c726d7353...   LOST
# 46605       46605  1134c0a7d44fdae1afd7f1f64e2789496784095ca0a050...   LOST
# 46606       46606  8b8b029f1142f5cbc825aa6cbee01406c915c6b055db79...   LOST
# 46607       46607  1ea65ea38f2f574b3875ba895e4ff76b284b7725041612...   LOST
#
#             lost_reason                budget  \
# ...

# %%
df['status'].unique()
# Out:
# array(['LOST', 'WON'], dtype=object)

# %%
len(df['lead_id'].unique())
# Out:
# 30491

# %% [markdown]
# # Removing Columns that will not be useful

# %%
df.drop(['movein','Unnamed: 0'], axis = 1, inplace=True)

# %%
df
# Out:
#                                                 Agent_id status  \
# 0      1deba9e96f404694373de9749ddd1ca8aa7bb823145a6f...   LOST
# 1      299ae77a4ef350ae0dd37d6bba1c002d03444fb1edb236...   LOST
# 2      c213697430c006013012dd2aca82dd9732aa0a1a6bca13...   LOST
# 3      eac9815a500f908736d303e23aa227f0957177b0e6756b...   LOST
# 4      1deba9e96f404694373de9749ddd1ca8aa7bb823145a6f...   LOST
# ...                                                  ...    ...
# 46603  2306878a9ad9b57686cd623dd285aaa9b25afdf627f651...   LOST
# 46604  327ec29056cc47c24bf922f7dc0f78261dad5c726d7353...   LOST
# 46605  1134c0a7d44fdae1afd7f1f64e2789496784095ca0a050...   LOST
# 46606  8b8b029f1142f5cbc825aa6cbee01406c915c6b055db79...   LOST
# 46607  1ea65ea38f2f574b3875ba895e4ff76b284b7725041612...   LOST
#
#             lost_reason                budget  \
# 0        Not responding                   NaN
# 1            Low budget                   NaN
# 2        Not responding  £121 - £180 Per Week
# ...

# %%
 #This'9b2d5b4678781e53038e91ea5324530a03f27dc1d0e5f6c9bc9d493a23be9de0' represents NaN and 
#could be present in more than one column.

# %%
df=df.replace('9b2d5b4678781e53038e91ea5324530a03f27dc1d0e5f6c9bc9d493a23be9de0', np.nan)
df
# Out:
#                                                 Agent_id status  \
# 0      1deba9e96f404694373de9749ddd1ca8aa7bb823145a6f...   LOST
# 1      299ae77a4ef350ae0dd37d6bba1c002d03444fb1edb236...   LOST
# 2      c213697430c006013012dd2aca82dd9732aa0a1a6bca13...   LOST
# 3      eac9815a500f908736d303e23aa227f0957177b0e6756b...   LOST
# 4      1deba9e96f404694373de9749ddd1ca8aa7bb823145a6f...   LOST
# ...                                                  ...    ...
# 46603  2306878a9ad9b57686cd623dd285aaa9b25afdf627f651...   LOST
# 46604  327ec29056cc47c24bf922f7dc0f78261dad5c726d7353...   LOST
# 46605  1134c0a7d44fdae1afd7f1f64e2789496784095ca0a050...   LOST
# 46606  8b8b029f1142f5cbc825aa6cbee01406c915c6b055db79...   LOST
# 46607  1ea65ea38f2f574b3875ba895e4ff76b284b7725041612...   LOST
#
#             lost_reason                budget  \
# 0        Not responding                   NaN
# 1            Low budget                   NaN
# 2        Not responding  £121 - £180 Per Week
# ...

# %% [markdown]
# # Handling null value

# %%
df.isnull().sum()
# Out:
# Agent_id              0
# status                0
# lost_reason        3073
# budget             3694
# lease              2336
# source             5951
# source_city        8831
# source_country     8622
# utm_source           61
# utm_medium         3184
# des_city           2529
# des_country        2529
# room_type         23491
# lead_id               0
# dtype: int64

# %%
round(100*(df.isnull().sum()/len(df.index)), 2)
# Out:
# Agent_id           0.00
# status             0.00
# lost_reason        6.63
# budget             7.98
# lease              5.04
# source            12.85
# source_city       19.07
# source_country    18.62
# utm_source         0.13
# utm_medium         6.87
# des_city           5.46
# des_country        5.46
# room_type         50.72
# lead_id            0.00
# dtype: float64

# %%
# we will drop the columns having more than 50% NA values.
df=df.drop(df.loc[:,list(round(100*(df.isnull().sum()/len(df.index)), 2)>50)].columns, 1)

# %%
 #Now we will take care of null values in each column one by one.

# %%
# we will use backward and forward value filling method

# %%
df = df.fillna(method='ffill').fillna(method='bfill')

# %%
df.isnull().sum()
# Out:
# Agent_id          0
# status            0
# lost_reason       0
# budget            0
# lease             0
# source            0
# source_city       0
# source_country    0
# utm_source        0
# utm_medium        0
# des_city          0
# des_country       0
# lead_id           0
# dtype: int64

# %%
df['lost_reason'].describe()
# Out:
# count                46317
# unique                  30
# top       Low availability
# freq                  9544
# Name: lost_reason, dtype: object

# %%
df['lost_reason'].unique()
# Out:
# array(['Not responding', 'Low budget', 'Junk lead',
#        'Wants private accommodation', 'Short stay', 'Booked with manager',
#        'Low availability', 'Not interested', 'Just Enquiring',
#        'Distance issue', 'Not serving in that region', 'No supply',
#        'Repeat lead', 'Not a student', 'Semester stay', 'Supply issue',
#        'Visa/admission denied', 'Inadequate details',
#        'Booked with competitor', 'Not going to university',
#        'Junk lead/ Just Enquiring', 'Lead issue',
#        'Booked on campus accommodation', 'Looking for admission',
#        'Underage student', 'Guarantor issue', "Didn't respond in time",
#        'Looking for loan', 'Looking for Scholarship', 'Cross sell'],
#       dtype=object)

# %%
df['budget'].describe()
# Out:
# count                   46317
# unique                   1851
# top       £60 - £120 Per week
# freq                    10538
# Name: budget, dtype: object

# %%
budget_stats=df['budget'].value_counts()
budget_stats
# Out:
# £60 - £120 Per week                                   10538
# £121 - £180 Per Week                                   9591
# 0-0                                                    6247
# £181 - £240 Per Week                                   2301
# 100                                                    1645
#                                                       ...
# 409                                                       1
# £180 - £190 Per Week                                      1
# 0-250 pounds but I'm looking to negotiate for less        1
# 0-$20                                                     1
# 0-500 PCM                                                 1
# Name: budget, Length: 1851, dtype: int64

# %%
l=[x for x in budget_stats  if x>10]
len(l)
# Out:
# 179

# %% [markdown]
# # Dimensionality Reduction

# %%
#Any budget having less than 10 data points should be tagged as "other" location. 
#This way number of categories can be reduced by huge amount.
#Later on when we do one hot encoding, it will help us with having fewer dummy columns

# %%
budget_stats_less_than_10 = budget_stats[budget_stats<=10]
budget_stats_less_than_10
# Out:
# 144                                                   10
# 390                                                   10
# 313                                                   10
# 150 pw                                                10
# 184                                                   10
#                                                       ..
# 409                                                    1
# £180 - £190 Per Week                                   1
# 0-250 pounds but I'm looking to negotiate for less     1
# 0-$20                                                  1
# 0-500 PCM                                              1
# Name: budget, Length: 1672, dtype: int64

# %%
df.budget = df.budget.apply(lambda x: 'other' if x in budget_stats_less_than_10 else x)
len(df.budget.unique())
# Out:
# 180

# %%
 #we can impute other in the missing values.

# %%
df['budget'].value_counts()
# Out:
# £60 - £120 Per week     10538
# £121 - £180 Per Week     9591
# 0-0                      6247
# other                    2988
# £181 - £240 Per Week     2301
#                         ...
# 222                        11
# 180/week                   11
# 0-350                      11
# 305                        11
# 235                        11
# Name: budget, Length: 180, dtype: int64

# %%
df['lease'].describe()
# Out:
# count                                   46317
# unique                                    311
# top       Full Year Course Stay 40 - 44 weeks
# freq                                    11505
# Name: lease, dtype: object

# %%
lease_stats=df['lease'].value_counts()
lease_stats
# Out:
# Full Year Course Stay 40 - 44 weeks           11505
# 0                                              7966
# Complete Education Year Stay 50 - 52 weeks     6796
# 51                                             4153
# Semester Stay 20 - 24 weeks                    2911
#                                               ...
# 1-2                                               1
# 6  onths                                          1
# 03 months                                         1
# 96                                                1
# 78                                                1
# Name: lease, Length: 311, dtype: int64

# %%
m=[x for x in lease_stats  if x>5]
len(m)
# Out:
# 88

# %%
lease_stats_less_than_5 = lease_stats[lease_stats<=5]
lease_stats_less_than_5
# Out:
# 32               5
# 20 - 24 weeks    5
# 1 year .         5
# 22               5
# 50 weeks         5
#                 ..
# 1-2              1
# 6  onths         1
# 03 months        1
# 96               1
# 78               1
# Name: lease, Length: 223, dtype: int64

# %%
df.lease = df.lease.apply(lambda x: 'other1' if x in lease_stats_less_than_5 else x)
len(df.lease.unique())
# Out:
# 89

# %%
#we can impute other in the missing values.

# %%
df['lease'].value_counts()
# Out:
# Full Year Course Stay 40 - 44 weeks           11505
# 0                                              7966
# Complete Education Year Stay 50 - 52 weeks     6796
# 51                                             4153
# Semester Stay 20 - 24 weeks                    2911
#                                               ...
# 4 weeks                                           8
# 14 weeks                                          6
# 4 months                                          6
# 56                                                6
# 44 - 51                                           6
# Name: lease, Length: 89, dtype: int64

# %%
df.isnull().sum()
# Out:
# Agent_id          0
# status            0
# lost_reason       0
# budget            0
# lease             0
# source            0
# source_city       0
# source_country    0
# utm_source        0
# utm_medium        0
# des_city          0
# des_country       0
# lead_id           0
# dtype: int64

# %%
df['source'].describe()
# Out:
# count                                                 46317
# unique                                                  682
# top       7aae3e886e89fc1187a5c47d6cea1c22998ee610ade1f2...
# freq                                                  22023
# Name: source, dtype: object

# %%
s_stats=df['source'].value_counts()
s_stats
# Out:
# 7aae3e886e89fc1187a5c47d6cea1c22998ee610ade1f2b7c51be879f0c37ca8    22023
# 7bcfca0e9d73371699b0adbf1c691e02108fa64f02f4dbe24a0217f139a9b916     4352
# ba2d0a29556ac20f86f45e4543c0825428cba33fd7a9eaa29e3f169d2ca43b2b     4150
# d684761c17c11590f6e2525b48141cb2c0c6f2be5df4e229dae06e64c5c41b64     2490
# 9ba9134a91cfc6b52ac8d480e9ad37896ca4ac216e2d795fdb7d75a63d6c60af     2448
#                                                                     ...
# ca2e202402aeae6f7ea5ec7c3168e93c97d19660aba70fe69b12a5bef71a68e2        1
# 9a0eba06d289b39d98edb47395b63ef1b1c8fc4cedc46671aa4f19b4eba70b0f        1
# 033a4a60dfe036110908aa92c4aa3c7ee43456a473f9a431e247ba8682178f47        1
# e8701697c0e359781a926b88eb0cdf6e919f85c38f0ebcb6bdcbb60b3abcb57a        1
# 93bee3e177d17c128e6a6af7b88fd675d7ec729b1a88ae13c582248dfd702378        1
# Name: source, Length: 682, dtype: int64

# %%
s_stats_less_than_10 = s_stats[s_stats<=10]
s_stats_less_than_10
# Out:
# aa784e1655aa8009fb61155d9c71935340ad00a4d7d8aceaf54d1b4fd6859e89    10
# cca6e68ea176f1ea07786b1054f16bb0c5e9c3a675490148ce6c2749567d5807    10
# f789909693b3898605450349b35d0218bc556c51f960f944e50ae242dc3446a3    10
# 2502b2dc9bc65b9b04f21eaf0b57d8e92e54aa29c62233f7b657f221305b636d    10
# 9ab9b659a836589f715b72165b0d32cad846412e62851c7b89f77c5aedf0df6c     9
#                                                                     ..
# ca2e202402aeae6f7ea5ec7c3168e93c97d19660aba70fe69b12a5bef71a68e2     1
# 9a0eba06d289b39d98edb47395b63ef1b1c8fc4cedc46671aa4f19b4eba70b0f     1
# 033a4a60dfe036110908aa92c4aa3c7ee43456a473f9a431e247ba8682178f47     1
# e8701697c0e359781a926b88eb0cdf6e919f85c38f0ebcb6bdcbb60b3abcb57a     1
# 93bee3e177d17c128e6a6af7b88fd675d7ec729b1a88ae13c582248dfd702378     1
# Name: source, Length: 588, dtype: int64

# %%
df.source = df.source.apply(lambda x: 'other2' if x in s_stats_less_than_10 else x)
len(df.source.unique())
# Out:
# 95

# %% [markdown]
# # feature selection

# %%
ls=df['lead_id'].value_counts()
len(ls)
# Out:
# 30491

# %%
df=df.drop('lead_id',axis=1)

# %%
df.isnull().sum()
# Out:
# Agent_id          0
# status            0
# lost_reason       0
# budget            0
# lease             0
# source            0
# source_city       0
# source_country    0
# utm_source        0
# utm_medium        0
# des_city          0
# des_country       0
# dtype: int64

# %%
df = df.replace(to_replace={'LOST':0,'WON':1})

# %%
df
# Out:
#                                                 Agent_id  status  \
# 0      1deba9e96f404694373de9749ddd1ca8aa7bb823145a6f...       0
# 1      299ae77a4ef350ae0dd37d6bba1c002d03444fb1edb236...       0
# 2      c213697430c006013012dd2aca82dd9732aa0a1a6bca13...       0
# 3      eac9815a500f908736d303e23aa227f0957177b0e6756b...       0
# 4      1deba9e96f404694373de9749ddd1ca8aa7bb823145a6f...       0
# ...                                                  ...     ...
# 46603  2306878a9ad9b57686cd623dd285aaa9b25afdf627f651...       0
# 46604  327ec29056cc47c24bf922f7dc0f78261dad5c726d7353...       0
# 46605  1134c0a7d44fdae1afd7f1f64e2789496784095ca0a050...       0
# 46606  8b8b029f1142f5cbc825aa6cbee01406c915c6b055db79...       0
# 46607  1ea65ea38f2f574b3875ba895e4ff76b284b7725041612...       0
#
#             lost_reason                budget  \
# 0        Not responding  £121 - £180 Per Week
# 1            Low budget  £121 - £180 Per Week
# ...

# %% [markdown]
# # Converting all categorical variables into dummy variables

# %%
data_dummies = pd.get_dummies(df)
data_dummies
# Out:
#        status  \
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 46603       0
# 46604       0
# 46605       0
# 46606       0
# 46607       0
#
#        Agent_id_04222ea3e14cb1209b9726defe3efce5196b7afa0a959854a30401be41f4026d  \
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 46603                                                  0
# 46604                                                  0
# 46605                                                  0
# 46606                                                  0
# 46607                                                  0
#
# ...

# %%
# Defining the variables that will enter the model:
x = data_dummies.drop('status',axis = 1)
x

y = data_dummies['status']

y.value_counts()
# Out:
# 0    43244
# 1     3073
# Name: status, dtype: int64

# %% [markdown]
# # Importing the necessary libraries

# %%
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score

# %%
x_train,x_test,y_train,y_test = train_test_split(x, y,test_size = 0.2)

# %%
#===== Logistic Regression =========================

# Creating the model:
model_lr=LogisticRegression(random_state=100)
 
# Fitting the Model
model_lr.fit(x_train, y_train)

# Predicting the data
y_pred=model_lr.predict(x_test)

#Metrics:
accuracy_lr = accuracy_score(y_test, y_pred, normalize=True)
f1_lr = f1_score(y_test, y_pred, average='binary')
re_lr=recall_score(y_test, y_pred, average='binary')

# %%
accuracy_lr
# Out:
# 0.9404145077720207

# %%
f1_lr
# Out:
# 0.3333333333333333

# %%
#===== Decision Tree Classifier =========================

# Creating the model:
model_dt = DecisionTreeClassifier( max_depth = 6, min_samples_leaf = 8)

# Fitting the Model (Using the training data to train the model):
model_dt.fit(x_train, y_train)
  
# Predicting the data and comparing the result with the test values:
y_pred = model_dt.predict(x_test)

accuracy_dt = accuracy_score(y_test, y_pred, normalize=True)
f1_dt = f1_score(y_test, y_pred, average='binary')
re_dt=recall_score(y_test, y_pred, average='binary')

# %%
accuracy_dt
# Out:
# 0.9353411053540587

# %%
f1_dt
# Out:
# 0.16920943134535368

# %%
#===== Random Forest Classifier =========================
    
# Creating the model:  
model_rf=RandomForestClassifier(n_estimators=100, criterion='gini', random_state = 100, max_depth=6, min_samples_leaf=8)
    
# Fitting the Model   
model_rf.fit(x_train,y_train)
    
# Predicting the data  
y_pred=model_rf.predict(x_test)

# Metrics:
accuracy_rf = accuracy_score(y_test, y_pred, normalize=True)
f1_rf = f1_score(y_test, y_pred, average='binary')
re_rf=recall_score(y_test, y_pred, average='binary')

# %%
#===== KNN =========================================
  
# Creating the model and Fitting the Model:
model_knn = KNeighborsClassifier(n_neighbors=7).fit(x_train, y_train)

# Predicting the data
y_pred = model_knn.predict(x_test)

# Metrics:
accuracy_knn = accuracy_score(y_test, y_pred, normalize=True)
f1_knn = f1_score(y_test, y_pred, average='binary')
re_knn = recall_score(y_test, y_pred, average='binary')

# %%
classification_metrics_accuracy = [accuracy_dt, accuracy_rf, accuracy_lr, 
                                     accuracy_knn]

classification_metrics_f1 = [f1_dt, f1_rf, f1_lr, f1_knn ]

classification_metrics_re =  [re_dt, re_rf, re_lr, re_knn ]

# %%
scores_df = pd.DataFrame(index=['Decision Tree', 'Random Forest', 'Logistic Regression', 'KNN'], 
columns=['Accuracy', 'F1', 'RECALL'])

scores_df['Accuracy'] = classification_metrics_accuracy
scores_df['F1'] = classification_metrics_f1
scores_df['RECALL'] = classification_metrics_re

scores_df.style.highlight_max(color = 'green')
# Out:
# <style type="text/css">
# #T_55f8e_row2_col0, #T_55f8e_row2_col1, #T_55f8e_row2_col2 {
#   background-color: green;
# }
# </style>
# <table id="T_55f8e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55f8e_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_55f8e_level0_col1" class="col_heading level0 col1" >F1</th>
#       <th id="T_55f8e_level0_col2" class="col_heading level0 col2" >RECALL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55f8e_level0_row0" class="row_heading level0 row0" >Decision Tree</th>
#       <td id="T_55f8e_row0_col0" class="data row0 col0" >0.935341</td>
#       <td id="T_55f8e_row0_col1" class="data row0 col1" >0.169209</td>
#       <td id="T_55f8e_row0_col2" class="data row0 col2" >0.097600</td>
#     </tr>
#     <tr>
#       <th id="T_55f8e_level0_row1" class="row_heading level0 row1" >Random Forest</th>
# ...
